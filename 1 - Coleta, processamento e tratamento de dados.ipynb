# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from unidecode import unidecode
from difflib import SequenceMatcher
import re
import requests
import joblib

# %% [markdown]
# # Processamento/tratamento de dados

# %% [markdown]
# ## Leitura do arquivo inicial com as compras.

# %%
df = pd.read_csv('arquivos/Arquivo inicial _202202191053.csv')

# %% [markdown]
# Breve verificação da integridade dos dados do arquivo.

# %%
df.head(10)
# Out:
#    id_pedido              data_pedido  id_cliente nome_cliente bairro_pedido  \
# 0         54  2020-07-03 11:30:53.000          39      Barbara       aldeota
# 1         54  2020-07-03 11:30:53.000          39      Barbara       aldeota
# 2         54  2020-07-03 11:30:53.000          39      Barbara       aldeota
# 3         54  2020-07-03 11:30:53.000          39      Barbara       aldeota
# 4         54  2020-07-03 11:30:53.000          39      Barbara       aldeota
# 5         54  2020-07-03 11:30:53.000          39      Barbara       aldeota
# 6         56  2020-07-03 11:32:27.000          38   Anna Karla   são gerardo
# 7         56  2020-07-03 11:32:27.000          38   Anna Karla   são gerardo
# 8         56  2020-07-03 11:32:27.000          38   Anna Karla   são gerardo
# 9         56  2020-07-03 11:32:27.000          38   Anna Karla   são gerardo
#
#   cidade_pedido cep_pedido          nome_produto  id_produto  \
# 0     Fortaleza   60150060               cajuína          54
# 1     Fortaleza   60150060          água de coco          56
# 2     Fortaleza   60150060                 couve          75
# 3     Fortaleza   60150060                 couve          75
# 4     Fortaleza   60150060         doce de leite          77
# 5     Fortaleza   60150060         queijo coalho          94
# 6     Fortaleza   60320105    arroz parboilizado          59
# 7     Fortaleza   60320105           banana maçã          60
# 8     Fortaleza   60320105          banana prata          61
# 9     Fortaleza   60320105  biscoito de castanha          63
#
#    qnt_itens_vendidos  preco_itens            tipo_pagamento  \
# 0                   3         10.0  Pagar ao retirar na loja
# 1                   2          3.0  Pagar ao retirar na loja
# 2                   1          3.0  Pagar ao retirar na loja
# 3                   1          3.0  Pagar ao retirar na loja
# 4                   1         12.0  Pagar ao retirar na loja
# 5                   2         25.0  Pagar ao retirar na loja
# 6                   1          6.0         Cartão de Crédito
# 7                   1          6.0         Cartão de Crédito
# 8                   2          5.0         Cartão de Crédito
# 9                   2          3.5         Cartão de Crédito
#
#                                               agente
# 0  Mozilla/5.0 (Linux; Android 9; motorola one zo...
# 1  Mozilla/5.0 (Linux; Android 9; motorola one zo...
# 2  Mozilla/5.0 (Linux; Android 9; motorola one zo...
# 3  Mozilla/5.0 (Linux; Android 9; motorola one zo...
# 4  Mozilla/5.0 (Linux; Android 9; motorola one zo...
# 5  Mozilla/5.0 (Linux; Android 9; motorola one zo...
# 6  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 7  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 9  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...

# %% [markdown]
# ## Significado dos campos
# Neste arquivo temos, em formato long, uma lista de pedidos realizados. A seguir encontra-se a descrição de cada coluna:
#
# - id_pedido: código único que identifica cada pedido;
# - data_pedido: data e hora em que os pedidos foram realizados;
# - id_cliente: código único que identifica o cliente que fez o pedido;
# - nome_cliente: nome do cliente que fez o pedido. Os nomes foram distorcidos para evitar identificação das pessoas;
# - bairro_pedido: bairro onde deve serfeita a entrega do pedido;
# - cidade_pedido: cidade onde deve ser feita a entrega do pedido;
# - cep_pedido: CEP onde deve ser feita a entrega do pedido;
# - nome_produto: nome do produto;
# - id_produto: código de identificação do produto;
# - qnt_itens_vendidos: quantidade de itens identificados por nome_produto e id_produto;
# - preco_itens: preço unitário do item;
# - tipo_pagamento: forma de pagamento;
# - agente: plataforma utilizada pelo cliente no momento em que fez o pedido.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36996 entries, 0 to 36995
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_pedido           36996 non-null  int64
#  1   data_pedido         36996 non-null  object
#  2   id_cliente          36996 non-null  int64
#  3   nome_cliente        36996 non-null  object
#  4   bairro_pedido       36505 non-null  object
#  5   cidade_pedido       36996 non-null  object
#  6   cep_pedido          36463 non-null  object
#  7   nome_produto        36996 non-null  object
#  8   id_produto          36996 non-null  int64
#  9   qnt_itens_vendidos  36996 non-null  int64
#  10  preco_itens         36996 non-null  float64
#  11  tipo_pagamento      36996 non-null  object
#  12  agente              36996 non-null  object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 3.7+ MB

# %% [markdown]
# ## Verificação de valores nulos

# %%
df.isnull().sum()
# Out:
# id_pedido               0
# data_pedido             0
# id_cliente              0
# nome_cliente            0
# bairro_pedido         491
# cidade_pedido           0
# cep_pedido            533
# nome_produto            0
# id_produto              0
# qnt_itens_vendidos      0
# preco_itens             0
# tipo_pagamento          0
# agente                  0
# dtype: int64

# %% [markdown]
# É possível verificar que temos valores nulos nas colunas de bairro e CEP. Podemos utilizar o CEP para descobrir o bairro, mas o inverso não é possível. Vamos, portanto, inicialmente, remover as linhas sem CEP.<p>
# O tratamento de bairros será feito mais à frente, portanto não excluiremos valores nulos nesta coluna neste momento.

# %%
ceps_nulos = df[df['cep_pedido'].isnull()]
df.drop(ceps_nulos.index,inplace=True)

# %% [markdown]
# ## Padronização dos códigos e nomes dos produtos
# Antes de qualquer coisa, para garantir os tratamentos que serão feitos mais à frente, vamos retirar caracteres maiúsculos e acentos dos nomes dos produtos.

# %%
df['nome_produto'] = df['nome_produto'].str.strip()
df['nome_produto'] = df['nome_produto'].str.lower()
df['nome_produto'] = df['nome_produto'].apply(lambda prod: unidecode(prod))

# %% [markdown]
# Nomes de produtos, como será possível verificar mais à frente, nos serão essenciais, portanto caso haja algum produto sem nome, deve ser removido. Acima já foi possível verificar que não há valores nulos na coluna de nomes de produtos, mas também precisamos procurar se temos espaços.

# %%
((df['nome_produto'].str.isspace()) | (df['nome_produto'] == '')).sum()
# Out:
# 0

# %% [markdown]
# Não há espaços. Prossigamos.

# %% [markdown]
# Percebe-se que há uma certa inconsistência tanto nos nomes quanto nos códigos dos produtos. Perceba os valores distintos nos contadores a seguir.

# %%
len(df['nome_produto'].unique())
# Out:
# 253

# %%
len(df['id_produto'].unique())
# Out:
# 177

# %% [markdown]
# Mais adiante utilizaremos os nomes para realizar análises, já que tratam-se de informações muito mais amigáveis, porém neste momento podemos nos utilizar do código para perceber que existem nomes distintos para um mesmo produto, o que acabará causando a divisão da contabilização de totais destes produtos em grupos distintos, o que afetará a análise.<P>
# Primeiramente vamos ver códigos de produto que estão sendo utilizados para mais de um nome de produto.

# %%
# Montando um dicionário onde as chaves são os ids de os valores são um set com os nomes de produtos.
prods = dict()
for idp in df['id_produto'].unique():
    nomes_id = df[df['id_produto'] == idp]['nome_produto'].unique()
    prods[idp] = set(nomes_id)

# Mostrando uma amostra de códidos de produtos que estão sendo utilizados para mais de um nome
i = int()
for id_p,nomes in prods.items():
    if len(nomes) != 1:
        i += 1
        if i > 5:
            break
        print(f"{id_p}: {nomes} - {len(nomes)} nomes distintos")
# Out:
# 54: {'cajuina 1l', 'cajuina'} - 2 nomes distintos
# 56: {'agua de coco [ garrafa 300ml ]', 'agua de coco'} - 2 nomes distintos
# 77: {'doce de leite [ pote ]', 'doce de leite'} - 2 nomes distintos
# 94: {'queijo coalho 1kg', 'queijo coalho (1kg)', 'queijo coalho'} - 3 nomes distintos
# 59: {'arroz parboilizado organico - 1kg', 'arroz parboilizado'} - 2 nomes distintos

# %% [markdown]
# Vamos verificar diretamente no data set se realmente há esta ambiguidade para os códigos de produto. Peguemos o código 54 como exemplo.

# %%
df[df['id_produto'] == 54][['id_produto','nome_produto']].sample(5,random_state=2)
# Out:
#        id_produto nome_produto
# 18988          54      cajuina
# 35674          54   cajuina 1l
# 16343          54      cajuina
# 20452          54      cajuina
# 25878          54      cajuina

# %% [markdown]
# É possível perceber que os nomes são muito parecidos. Optaremos, portanto, em padronizá-los adotando como nome a porção similar entre eles. Por exemplo, entre <i>cajuina 1l</i> e <i>cajuina</i> ficaremos com <i>cajuina</i>.

# %%
# Primeiramente vamos criar uma função que compara dois strings e retorna a porção similar entre eles.
def texto_igual(a,b):
    sm = SequenceMatcher(None,a,b).get_matching_blocks()
    str_sim = (a[sm[0][0]:sm[0][0] + sm[0][2]]).strip()
    return str_sim


# Tratamento dos nomes dos produtos, colocando os nomes de produtos definitivo no DataFrame.
nomes_def = dict() # Chave: código de produto, valor: nome definitivo atrelado ao código
nome_def = str() # Necessário para guardar o texto comum quanto há mais de dois nomes.

# Iterando entre os ids com produtos duplicados e selecionando o nome definitivo.
for id_p,nomes in prods.items():
    if len(nomes) == 1: # Só um nome. Não é preciso verificação.
        nomes_def[id_p] = nomes.pop()
            
    else: 
        for i,nome in enumerate(nomes): # É preciso comparar todas ocorrências. Há casos onde há mais de dois nomes.
            if i == 0: # O primeiro nome se torna a  base de comparação
                nome_def = nome
            else:
                nome_def = texto_igual(nome_def,nome)

        nomes_def[id_p] = nome_def
    
df['nome_produto'] = df.id_produto.map(nomes_def)

# %% [markdown]
# Verificando se a alteração surtiu efeito.

# %%
df[df['id_produto'] == 54][['id_produto','nome_produto']].sample(5,random_state=2)
# Out:
#        id_produto nome_produto
# 18988          54      cajuina
# 35674          54      cajuina
# 16343          54      cajuina
# 20452          54      cajuina
# 25878          54      cajuina

# %% [markdown]
# Vamos fazer mais uma comparação da quantidade de valores únicos nos campos de id de produto e código de produto, Se tudo estiver íntegro, as quantidades deveriam estar iguais.

# %%
len(df['id_produto'].unique())
# Out:
# 177

# %%
len(df['nome_produto'].unique())
# Out:
# 176

# %% [markdown]
# Ficamos com a situação contrária. Há mais ids do que nomes de produto. Vamos descobrir quais são usando a mesma lógica utilizada anteriormente, porém invertendo os campos.

# %%
ids = dict()
for nome in df['nome_produto'].unique():
    ids_nome = df[df['nome_produto'] == nome]['id_produto'].unique()
    ids[nome] = set(ids_nome)

i = int()
for nome,ids_nome in ids.items():
    if len(ids_nome) != 1:
        i += 1
        if i > 5:
            break
        print(f"{nome}: {ids_nome} - {len(ids_nome)} ids distintos")
# Out:
# arroz: {200, 57} - 2 ids distintos

# %% [markdown]
# Como se trata de uma única ocorrência, vamos corrigir o valor manualmente.

# %%
df['id_produto'].replace({200:57},inplace=True)

# %% [markdown]
# Finalmente os campos estão íntegros e com redundâncias tratadas, conforme é possível ver nos contadores a seguir.

# %%
len(df['nome_produto'].unique())
# Out:
# 176

# %%
len(df['id_produto'].unique())
# Out:
# 176

# %% [markdown]
# Em passos posteriores, pecebemos que um código específico não estava sendo resolvido pelo tratamento automático devido à maneira como seus nomes foram cadastrados. <i><b>C</b>olorau</i>, <i><b>c</b>orante de urucum</i> e <i><b>c</b>orante de urucum [ 200 g ]</i>. O nome de produto resultante do processo automático estava sendo <b>c</b>. Por esta razão, este é o único produto que necessita de intervenção manual.

# %%
df['nome_produto'] = df['nome_produto'].replace({'c':'corante de urucum'})

# %% [markdown]
# O id do produto não nos tem mais serventia. Vamos excluí-lo.

# %%
df.drop('id_produto',axis=1,inplace=True)

# %% [markdown]
# ## Tratamento e validação do conteúdo das colunas
# É necessária análise e tratamento do conteúdo de todas as colunas para avaliar de qual forma seus conteúdos poderão ser utilizados.<p>

# %% [markdown]
# ### id_cliente
# Vamos verificar se algum id do cliente tem mais de um nome. Como o id do cliente será utilizado mais para frente, seu compartilhamento entre vários clientes estaria totalizando vários clientes como um só, o que pode afetar nossa análise.

# %%
ids_clientes = df['id_cliente'].unique()

for id_cliente in ids_clientes:
    nomes_id = df[df['id_cliente'] == id_cliente]['nome_cliente'].unique()
    if len(nomes_id) > 1:
        print(f"{id_cliente}: {nomes_id} - {len(nomes_id)} nomes")
# Out:
# 0: ['Riviane ' 'Ticiana ' 'Stefanie' 'Karla Maria' 'Vanessa' 'Tatiany' 'José'
#  'Celecina ' 'daniel kayo' 'silvia' 'MARIA JOSE ' 'Sheila' 'Rita '
#  'Lorena' 'Margareth ' 'Mayra' 'Cinthia' 'samya' 'Indra' 'Virna ' 'Sônia'
#  'Vicente' 'Tatiana ' 'Naggila' 'Rodrigo ' 'Juliana ' 'Marcos'
#  'LUIZA ADRIANA' 'Rita' 'Rafaela' 'Samya' 'Margareth' 'claudene ' 'Naike'
#  'Maria do Carmo ' 'Annya' 'Raíssa' 'Rosane' 'Pedro' 'Ercilia' 'jullyana '
#  'Beatriz ' 'Rosilene ' 'Rebeca' 'Ana Cristina' 'Carlos ' 'Tatiany '
#  'Daniel' 'Keyla' 'Paulo Marcelo' 'Amanda' 'Rayanne ' 'Samira'
#  'Francisco Maxshwell dos Santos ' 'Talisson' 'Rosilene' 'Leonardo'
#  'Paolla ' 'Gema Galgani Silveira' 'Maria Auxiliadora ' 'Lina'
#  'Guilherme ' 'Gracas' 'Paolla' 'Indra ' 'CLAUDIA MARIA' 'Gabriel '
#  'Nathan' 'Jessica' 'MARGARETH' 'Salete' 'Elizabete ' 'Jacinta Márcia'
#  'Karine' 'João Paulo' 'Nathalia' 'Luz Elena ' 'Noandro '] - 78 nomes

# %% [markdown]
# Há 78 nomes compartilhando o id 0. Vamos criar 78 ids fictícios para cada um desses nomes, mas antes vamos verificar a quantidade de ids únicos para validar a alteração que será feita.

# %%
len(df['id_cliente'].unique())
# Out:
# 1123

# %% [markdown]
# Vamos às alterações.

# %%
# Criando um dicionário com um id fictício para cada nome
fake_id = 9999
dic_nomes = dict()
nomes = df[df['id_cliente'] == 0]['nome_cliente'].unique()

for nome in nomes:
    dic_nomes[nome] = fake_id
    fake_id -= 1

# Transformando ids zerados em seus respectivos nomes
df['id_cliente'] = np.where(df['id_cliente'] == 0, df['nome_cliente'],df['id_cliente'])

# Substituindo nomes por id ficitício na coluna de ids
df['id_cliente'].replace(dic_nomes,inplace=True)

# %% [markdown]
# Vamos validar as alterações feitas verificando a quantidade de ids de cliente únicos. Deveríamos ter a quantidade original + 78 ficítícios - 1, que é o zero que foi eliminado.

# %%
len(df['id_cliente'].unique())
# Out:
# 1200

# %% [markdown]
# ### nome_cliente
# A coluna com o nome do cliente não será utilizada, portanto podemos removê-la.

# %%
df.drop('nome_cliente',axis=1,inplace=True)

# %% [markdown]
# ### agente
# A coluna mostra a plataforma utilizada pelo cliente, porém de maneira pouco amigável. Vamos simplificá-la criando 8 classes:

# %%
def retorna_agente(agente):
    if 'android' in agente.lower():
        return 'android'
    elif 'ipad' in agente.lower():
        return 'ipad'
    elif 'iphone' in agente.lower():
        return 'iphone'
    elif 'macintosh' in agente.lower():
        return 'macintosh'
    elif 'windows' in agente.lower():
        return 'windows'
    elif 'linux' in agente.lower():
        return 'linux'
    elif 'x11' in agente.lower():
        return 'x11'
    return 'desconhecido'

df['agente'] = df['agente'].apply(retorna_agente)

# %% [markdown]
# ### cidade_pedido e bairro_pedido
# Como são informações manualmente preenchidas pelo cliente, podem conter erros de digitação ou diferenças devido a letras maiúsculas, minúsculas e acentos. Como mais a frente pretendemos fazer análises totalizando valores por bairro e cidade, é interessante que tenhamos estas informações padronizadas. Para tanto, nos utilizaremos de arquivo csv gerado com ***1.2 - Captura de bairros e cidades a partir do CEP.ipynb***.

# %%
df_ends = pd.read_csv('arquivos/Endereços dos CEPs.csv',dtype={'cep':'string'})
df_ends.head()
# Out:
#         cep           bairro     cidade
# 0  60150060          aldeota  fortaleza
# 1  60320105      sao gerardo  fortaleza
# 2  60713480    manoel satiro  fortaleza
# 3  60431075  rodolfo teofilo  fortaleza
# 4  60430660  rodolfo teofilo  fortaleza

# %% [markdown]
# É preciso deixar o CEP no DataFrame de compras no mesmo formato que acabou de ser lido no arquivo que foi guardado em <code>df_ends</code>.

# %%
df['cep_pedido'] = df['cep_pedido'].apply(lambda cep: re.sub('[^0-9]','',cep))
df['cep_pedido'] = df['cep_pedido'].apply(lambda cep: f"{int(cep):08d}")

# %% [markdown]
# Vamos primeiramente definir uma função que recebe CEP, bairro e endereço e retorna as informações presentes no arquivo correspondentes ao CEP informado. Bairro e endereço também devem ser recebidos para que possam ser retornados caso o CEP não esteja presente no arquivo. Tal lógica foi adotada para evitarmos de perder, no DataFrame, informação de cidade e bairro para casos onde foi informado um CEP inválido.<p>
# Além disso, CEPs inválidos serão zerados.

# %%
df.reset_index(drop=True, inplace=True) # Necessário pois linhas foram "dropadas" e o índice não está mais contínuo.

def busca_end(cep,bairro,cidade):
    if cep in list(df_ends['cep']):
        bairro_lido = df_ends[df_ends['cep'] == cep]['bairro'].to_string(index=False)
        cidade_lida = df_ends[df_ends['cep'] == cep]['cidade'].to_string(index=False)
        return cep,bairro_lido,cidade_lida
    else:
        return '0'*8,bairro,cidade

ends_finais = df[['cep_pedido','bairro_pedido','cidade_pedido']].apply(
    lambda df: busca_end(df['cep_pedido'],df['bairro_pedido'],df['cidade_pedido']),axis=1)
    
df['cep_pedido'] = pd.DataFrame(list(ends_finais))[0]
df['bairro_pedido'] = pd.DataFrame(list(ends_finais))[1]
df['cidade_pedido'] = pd.DataFrame(list(ends_finais))[2]

# %% [markdown]
# Cidades e bairros de registros cujo CEP não é válido podem ter ficado com caracteres maiúsculos, espaços desnecessários ou acentos. Vamos retirá-los.

# %%
df['bairro_pedido'].fillna(' ',inplace=True)
df['bairro_pedido'] = df['bairro_pedido'].map(str)
df['bairro_pedido'] = df['bairro_pedido'].str.strip()
df['bairro_pedido'] = df['bairro_pedido'].str.lower()
df['bairro_pedido'] = df['bairro_pedido'].apply(lambda prod: unidecode(prod))

df['cidade_pedido'].fillna(' ',inplace=True)
df['cidade_pedido'] = df['cidade_pedido'].map(str)
df['cidade_pedido'] = df['cidade_pedido'].str.strip()
df['cidade_pedido'] = df['cidade_pedido'].str.lower()
df['cidade_pedido'] = df['cidade_pedido'].apply(lambda prod: unidecode(prod))

# %% [markdown]
# Vamos verificar a situação final deste campos.

# %%
df['cidade_pedido'].value_counts()
# Out:
# fortaleza    35570
# caucaia        447
# maracanau      171
# aquiraz        125
# osasco          57
# fortim          44
# eusebio         35
# salvador         9
# sao paulo        3
# itaitinga        2
# Name: cidade_pedido, dtype: int64

# %%
df['bairro_pedido'].value_counts()
# Out:
# meireles             4666
# aldeota              2832
# joaquim tavora       2744
# benfica              2278
# fatima               1950
#                      ...
# parque leblon           2
# pari                    1
# parque santa rosa       1
# republica               1
# vila mariana            1
# Name: bairro_pedido, Length: 132, dtype: int64

# %% [markdown]
# ### data_pedido
# A data do pedido está como 'object'. Vamos transformá-la em datetime e separar data e hora em duas colunas distintas.

# %%
df['hora_pedido'] = pd.to_datetime(df['data_pedido']).dt.time
df['data_pedido'] = pd.to_datetime(df['data_pedido']).dt.date

# %% [markdown]
# ### Categoria do produto
# Utilizando um modelo treinado em ***1.1 - Treinamento de modelo para classificação de categoria.ipynb***, vamos acrescentar uma coluna que informa a categoria do produto.

# %%
modelo_categ = joblib.load('arquivos/modelos/modelo_nb_classificacao_categorias.pkl')
tfidf_categ = joblib.load('arquivos/modelos/tfidf_classificacao_categorias.pkl')
prods_tfidf = tfidf_categ.transform(df['nome_produto'])
df['categoria'] = modelo_categ.predict(prods_tfidf)

# %% [markdown]
# ### Unificação de produtos duplicados em um mesmo pedido
# Perceba que o produto *couve* aparece duas vezes no pedido 54.

# %%
df.head()
# Out:
#    id_pedido data_pedido  id_cliente bairro_pedido cidade_pedido cep_pedido  \
# 0         54  2020-07-03          39       aldeota     fortaleza   60150060
# 1         54  2020-07-03          39       aldeota     fortaleza   60150060
# 2         54  2020-07-03          39       aldeota     fortaleza   60150060
# 3         54  2020-07-03          39       aldeota     fortaleza   60150060
# 4         54  2020-07-03          39       aldeota     fortaleza   60150060
#
#     nome_produto  qnt_itens_vendidos  preco_itens            tipo_pagamento  \
# 0        cajuina                   3         10.0  Pagar ao retirar na loja
# 1   agua de coco                   2          3.0  Pagar ao retirar na loja
# 2          couve                   1          3.0  Pagar ao retirar na loja
# 3          couve                   1          3.0  Pagar ao retirar na loja
# 4  doce de leite                   1         12.0  Pagar ao retirar na loja
#
#     agente hora_pedido                        categoria
# 0  android    11:30:53  sucos refrescos e refrigerantes
# 1  android    11:30:53          agua energeticos e chas
# 2  android    11:30:53                         verduras
# 3  android    11:30:53                         verduras
# 4  android    11:30:53               doces e sobremesas

# %% [markdown]
# Vamos unificar essas linhas, somando a quantidade de produtos.

# %%
colunas = list(df.columns)
colunas.remove('qnt_itens_vendidos')

df = df.groupby(colunas).agg({'qnt_itens_vendidos':['sum']})
df.reset_index(inplace=True)
df.columns = [col[0] for col in df.columns]

# %% [markdown]
# ### Criação de coluna de valor total dos produtos.
# Por enquanto só temos uma coluna com o valor unitário. Vamos criar uma coluna com o total gasto com todos os itens.

# %%
# Melhorando o nome de algumas colunas
df.columns = [col if col != 'preco_itens' else 'vl_unitario' for col in list(df.columns)]
df.columns = [col if col != 'qnt_itens_vendidos' else 'qt_itens' for col in list(df.columns)]

# Criando a nova coluna
df['vl_total'] = (df['qt_itens'] * df['vl_unitario']).round(2)

# %% [markdown]
# Vamos dar uma olhada no DataFrame após todos os tratamentos realizados.

# %%
df.head()
# Out:
#    id_pedido data_pedido  id_cliente bairro_pedido cidade_pedido cep_pedido  \
# 0         54  2020-07-03          39       aldeota     fortaleza   60150060
# 1         54  2020-07-03          39       aldeota     fortaleza   60150060
# 2         54  2020-07-03          39       aldeota     fortaleza   60150060
# 3         54  2020-07-03          39       aldeota     fortaleza   60150060
# 4         54  2020-07-03          39       aldeota     fortaleza   60150060
#
#     nome_produto  vl_unitario            tipo_pagamento   agente hora_pedido  \
# 0   agua de coco          3.0  Pagar ao retirar na loja  android    11:30:53
# 1        cajuina         10.0  Pagar ao retirar na loja  android    11:30:53
# 2          couve          3.0  Pagar ao retirar na loja  android    11:30:53
# 3  doce de leite         12.0  Pagar ao retirar na loja  android    11:30:53
# 4  queijo coalho         25.0  Pagar ao retirar na loja  android    11:30:53
#
#                          categoria  qt_itens  vl_total
# 0          agua energeticos e chas         2       6.0
# 1  sucos refrescos e refrigerantes         3      30.0
# 2                         verduras         2       6.0
# 3               doces e sobremesas         1      12.0
# 4                          queijos         2      50.0

# %% [markdown]
# ## Criação de DataFrame em formato wide.
# Até então visualizamos os dados somente em formato long, com uma linha por produto, havendo, portanto, várias linhas por pedido. Para diversas análises que pretendemos fazer, é necessário termos os dados em formato wide, ou seja, havendo somente uma linha por produto.<p>
# Criaremos, portanto, mais um DataFrame, onde cada produto será representado por variáveis dummy, havendo uma coluna por quantidade de cada produto e outra para o valor do item. Também acrescentaremos uma coluna com o valor total e outra com a quantidade total de itens da compra, que poderão ser úteis em algumas análises.

# %%
pedidos = dict()

for i in range(0,len(df)):
    linha = df.iloc[i]
    if linha['id_pedido'] not in pedidos.keys():
        pedidos[linha['id_pedido']] = {'data_pedido':linha['data_pedido'],
                                       'hora_pedido':linha['hora_pedido'],
                                       'id_cliente':linha['id_cliente'],
                                       'bairro_pedido':linha['bairro_pedido'],
                                       'cidade_pedido':linha['cidade_pedido'],
                                       'cep_pedido':linha['cep_pedido'],
                                       'tipo_pagamento':linha['tipo_pagamento'],
                                       'agente':linha['agente'],
                                       'i_' + linha['nome_produto']:True,
                                       'qt_'+linha['nome_produto']:linha['qt_itens'],
                                       'vl_tot_'+linha['nome_produto']:linha['vl_total'],
                                       'vl_final_pedido':linha['vl_total'],
                                       'qt_final_itens': linha['qt_itens']}
    else:
        pedidos[linha['id_pedido']]['vl_final_pedido'] += linha['vl_total']
        pedidos[linha['id_pedido']]['qt_final_itens'] += linha['qt_itens']
        pedidos[linha['id_pedido']]['i_' + linha['nome_produto']] = True
        pedidos[linha['id_pedido']]['qt_'+linha['nome_produto']] = linha['qt_itens']
        pedidos[linha['id_pedido']]['vl_tot_'+linha['nome_produto']] = linha['vl_total']

df_ped = pd.DataFrame.from_dict(pedidos,orient='index')
df_ped = df_ped.round(2) # Para eliminar dízimas periódicas

# %% [markdown]
# Data frame de pedidos criado. Vamos dar uma olhada nele.

# %%
df_ped.head()
# Out:
#    data_pedido hora_pedido  id_cliente    bairro_pedido cidade_pedido  \
# 54  2020-07-03    11:30:53          39          aldeota     fortaleza
# 56  2020-07-03    11:32:27          38      sao gerardo     fortaleza
# 59  2020-07-03    11:38:01          35    manoel satiro     fortaleza
# 60  2020-07-03    11:38:27          33  rodolfo teofilo     fortaleza
# 64  2020-07-03    11:49:13          40  rodolfo teofilo     fortaleza
#
#    cep_pedido            tipo_pagamento   agente i_agua de coco  \
# 54   60150060  Pagar ao retirar na loja  android           True
# 56   60320105         Cartão de Crédito  windows            NaN
# 59   60713480         Cartão de Crédito  windows            NaN
# 60   60431075      Débito/Transferência  android           True
# 64   60430660         Cartão de Crédito  android            NaN
#
#     qt_agua de coco  ...  vl_tot_pimentao [ 500g ]  i_abobrinha  qt_abobrinha  \
# 54              2.0  ...                       NaN          NaN           NaN
# 56              NaN  ...                       NaN          NaN           NaN
# 59              NaN  ...                       NaN          NaN           NaN
# 60              2.0  ...                       NaN          NaN           NaN
# 64              NaN  ...                       NaN          NaN           NaN
#
#    vl_tot_abobrinha  i_quiabo [ kg ]  qt_quiabo [ kg ] vl_tot_quiabo [ kg ]  \
# 54              NaN              NaN               NaN                  NaN
# 56              NaN              NaN               NaN                  NaN
# 59              NaN              NaN               NaN                  NaN
# 60              NaN              NaN               NaN                  NaN
# 64              NaN              NaN               NaN                  NaN
#
#     i_pepino amarelo [ unidade ]  qt_pepino amarelo [ unidade ]  \
# 54                           NaN                            NaN
# 56                           NaN                            NaN
# 59                           NaN                            NaN
# 60                           NaN                            NaN
# 64                           NaN                            NaN
#
#    vl_tot_pepino amarelo [ unidade ]
# 54                               NaN
# 56                               NaN
# 59                               NaN
# 60                               NaN
# 64                               NaN
#
# [5 rows x 538 columns]

# %% [markdown]
# É possível perceber que ficamos com muitos valores nulos nesta matriz esparsa de items de cada pedido. Vamos verificar a quantidade de valores nulos por coluna.

# %%
pd.set_option("display.max_rows", 540)
df_ped.isnull().sum()
# Out:
# data_pedido                                                                                                      0
# hora_pedido                                                                                                      0
# id_cliente                                                                                                       0
# bairro_pedido                                                                                                    0
# cidade_pedido                                                                                                    0
# cep_pedido                                                                                                       0
# tipo_pagamento                                                                                                   0
# agente                                                                                                           0
# i_agua de coco                                                                                                3125
# qt_agua de coco                                                                                               3125
# vl_tot_agua de coco                                                                                           3125
# vl_final_pedido                                                                                                  0
# qt_final_itens                                                                                                   0
# i_cajuina                                                                                                     2499
# qt_cajuina                                                                                                    2499
# vl_tot_cajuina                                                                                                2499
# i_couve                                                                                                       2141
# qt_couve                                                                                                      2141
# vl_tot_couve                                                                                                  2141
# i_doce de leite                                                                                               2842
# qt_doce de leite                                                                                              2842
# vl_tot_doce de leite                                                                                          2842
# i_queijo coalho                                                                                               2648
# qt_queijo coalho                                                                                              2648
# vl_tot_queijo coalho                                                                                          2648
# i_arroz parboilizado                                                                                          3399
# qt_arroz parboilizado                                                                                         3399
# vl_tot_arroz parboilizado                                                                                     3399
# i_banana maca                                                                                                 3007
# qt_banana maca                                                                                                3007
# vl_tot_banana maca                                                                                            3007
# i_banana prata                                                                                                1994
# qt_banana prata                                                                                               1994
# vl_tot_banana prata                                                                                           1994
# i_biscoito de castanha                                                                                        2682
# qt_biscoito de castanha                                                                                       2682
# vl_tot_biscoito de castanha                                                                                   2682
# i_carne de carneiro                                                                                           3078
# qt_carne de carneiro                                                                                          3078
# vl_tot_carne de carneiro                                                                                      3078
# i_castanha de caju (natural)                                                                                  2489
# qt_castanha de caju (natural)                                                                                 2489
# vl_tot_castanha de caju (natural)                                                                             2489
# i_feijao de corda                                                                                             2939
# qt_feijao de corda                                                                                            2939
# vl_tot_feijao de corda                                                                                        2939
# i_jerimum leite                                                                                               2818
# qt_jerimum leite                                                                                              2818
# vl_tot_jerimum leite                                                                                          2818
# i_limao                                                                                                       2090
# qt_limao                                                                                                      2090
# vl_tot_limao                                                                                                  2090
# i_mel de abelha                                                                                               2750
# qt_mel de abelha                                                                                              2750
# vl_tot_mel de abelha                                                                                          2750
# i_ovos caipira                                                                                                2164
# qt_ovos caipira                                                                                               2164
# vl_tot_ovos caipira                                                                                           2164
# i_cachaca                                                                                                     3372
# qt_cachaca                                                                                                    3372
# vl_tot_cachaca                                                                                                3372
# i_cafe (500g)                                                                                                 3479
# qt_cafe (500g)                                                                                                3479
# vl_tot_cafe (500g)                                                                                            3479
# i_carne de porco                                                                                              3065
# qt_carne de porco                                                                                             3065
# vl_tot_carne de porco                                                                                         3065
# i_doce de goiaba                                                                                              3136
# qt_doce de goiaba                                                                                             3136
# vl_tot_doce de goiaba                                                                                         3136
# i_goma                                                                                                        3118
# qt_goma                                                                                                       3118
# vl_tot_goma                                                                                                   3118
# i_macaxeira                                                                                                   2828
# qt_macaxeira                                                                                                  2828
# vl_tot_macaxeira                                                                                              2828
# i_mamao                                                                                                       2265
# qt_mamao                                                                                                      2265
# vl_tot_mamao                                                                                                  2265
# i_oleo de coco                                                                                                3337
# qt_oleo de coco                                                                                               3337
# vl_tot_oleo de coco                                                                                           3337
# i_cocada branca                                                                                               2995
# qt_cocada branca                                                                                              2995
# vl_tot_cocada branca                                                                                          2995
# i_coco verde                                                                                                  3122
# qt_coco verde                                                                                                 3122
# vl_tot_coco verde                                                                                             3122
# i_queijo coalho (500g)                                                                                        2672
# qt_queijo coalho (500g)                                                                                       2672
# vl_tot_queijo coalho (500g)                                                                                   2672
# i_quiabo                                                                                                      3477
# qt_quiabo                                                                                                     3477
# vl_tot_quiabo                                                                                                 3477
# i_batata doce                                                                                                 2357
# qt_batata doce                                                                                                2357
# vl_tot_batata doce                                                                                            2357
# i_bone de cuba                                                                                                3381
# qt_bone de cuba                                                                                               3381
# vl_tot_bone de cuba                                                                                           3381
# i_molho de pimenta                                                                                            3330
# qt_molho de pimenta                                                                                           3330
# vl_tot_molho de pimenta                                                                                       3330
# i_cafe                                                                                                        3250
# qt_cafe                                                                                                       3250
# vl_tot_cafe                                                                                                   3250
# i_galinha caipira                                                                                             3044
# qt_galinha caipira                                                                                            3044
# vl_tot_galinha caipira                                                                                        3044
# i_manteiga da terra                                                                                           3172
# qt_manteiga da terra                                                                                          3172
# vl_tot_manteiga da terra                                                                                      3172
# i_caneca mst                                                                                                  3456
# qt_caneca mst                                                                                                 3456
# vl_tot_caneca mst                                                                                             3456
# i_caneca mst (branco/vermelho)                                                                                3465
# qt_caneca mst (branco/vermelho)                                                                               3465
# vl_tot_caneca mst (branco/vermelho)                                                                           3465
# i_palitos de cana-de-acucar                                                                                   3382
# qt_palitos de cana-de-acucar                                                                                  3382
# vl_tot_palitos de cana-de-acucar                                                                              3382
# i_macaxeira pre-cozida                                                                                        2900
# qt_macaxeira pre-cozida                                                                                       2900
# vl_tot_macaxeira pre-cozida                                                                                   2900
# i_castanha de caju (salgada)                                                                                  2977
# qt_castanha de caju (salgada)                                                                                 2977
# vl_tot_castanha de caju (salgada)                                                                             2977
# i_farinha de mandioca amarela                                                                                 3332
# qt_farinha de mandioca amarela                                                                                3332
# vl_tot_farinha de mandioca amarela                                                                            3332
# i_gordura de porco                                                                                            3349
# qt_gordura de porco                                                                                           3349
# vl_tot_gordura de porco                                                                                       3349
# i_mascara de tecido                                                                                           3389
# qt_mascara de tecido                                                                                          3389
# vl_tot_mascara de tecido                                                                                      3389
# i_bolo de milho                                                                                               3369
# qt_bolo de milho                                                                                              3369
# vl_tot_bolo de milho                                                                                          3369
# i_arroz integral                                                                                              3264
# qt_arroz integral                                                                                             3264
# vl_tot_arroz integral                                                                                         3264
# i_farinha de mandioca branca                                                                                  3293
# qt_farinha de mandioca branca                                                                                 3293
# vl_tot_farinha de mandioca branca                                                                             3293
# i_jerimum caboclo                                                                                             2965
# qt_jerimum caboclo                                                                                            2965
# vl_tot_jerimum caboclo                                                                                        2965
# i_arroz                                                                                                       3052
# qt_arroz                                                                                                      3052
# vl_tot_arroz                                                                                                  3052
# i_bone do mst                                                                                                 3400
# qt_bone do mst                                                                                                3400
# vl_tot_bone do mst                                                                                            3400
# i_sal temperado                                                                                               3158
# qt_sal temperado                                                                                              3158
# vl_tot_sal temperado                                                                                          3158
# i_livro                                                                                                       3522
# qt_livro                                                                                                      3522
# vl_tot_livro                                                                                                  3522
# i_livro - de onde vem nossa comida?                                                                           3508
# qt_livro - de onde vem nossa comida?                                                                          3508
# vl_tot_livro - de onde vem nossa comida?                                                                      3508
# i_alface crespa                                                                                               2578
# qt_alface crespa                                                                                              2578
# vl_tot_alface crespa                                                                                          2578
# i_avental do mst - vermelho                                                                                   3445
# qt_avental do mst - vermelho                                                                                  3445
# vl_tot_avental do mst - vermelho                                                                              3445
# i_livro - florestan fernandes: reflexoes sobre a construcao de um instrumento politico                        3514
# qt_livro - florestan fernandes: reflexoes sobre a construcao de um instrumento politico                       3514
# vl_tot_livro - florestan fernandes: reflexoes sobre a construcao de um instrumento politico                   3514
# i_geleia de abacaxi com hortela e gergelim                                                                    3497
# qt_geleia de abacaxi com hortela e gergelim                                                                   3497
# vl_tot_geleia de abacaxi com hortela e gergelim                                                               3497
# i_avental do mst - preto                                                                                      3499
# qt_avental do mst - preto                                                                                     3499
# vl_tot_avental do mst - preto                                                                                 3499
# i_corante de urucum                                                                                           3202
# qt_corante de urucum                                                                                          3202
# vl_tot_corante de urucum                                                                                      3202
# i_livro - algumas plantas indicadoras                                                                         3521
# qt_livro - algumas plantas indicadoras                                                                        3521
# vl_tot_livro - algumas plantas indicadoras                                                                    3521
# i_livro - sopro da vida                                                                                       3504
# qt_livro - sopro da vida                                                                                      3504
# vl_tot_livro - sopro da vida                                                                                  3504
# i_toucinho de porco                                                                                           3374
# qt_toucinho de porco                                                                                          3374
# vl_tot_toucinho de porco                                                                                      3374
# i_geleia de mamao com canela                                                                                  3479
# qt_geleia de mamao com canela                                                                                 3479
# vl_tot_geleia de mamao com canela                                                                             3479
# i_geleia de pimenta com uvas passas                                                                           3472
# qt_geleia de pimenta com uvas passas                                                                          3472
# vl_tot_geleia de pimenta com uvas passas                                                                      3472
# i_caneca lgbt                                                                                                 3507
# qt_caneca lgbt                                                                                                3507
# vl_tot_caneca lgbt                                                                                            3507
# i_livro - iemanja, a deusa do mar                                                                             3521
# qt_livro - iemanja, a deusa do mar                                                                            3521
# vl_tot_livro - iemanja, a deusa do mar                                                                        3521
# i_geleia de maca com castanha e pimenta                                                                       3499
# qt_geleia de maca com castanha e pimenta                                                                      3499
# vl_tot_geleia de maca com castanha e pimenta                                                                  3499
# i_caneca da feira da reforma agraria                                                                          3523
# qt_caneca da feira da reforma agraria                                                                         3523
# vl_tot_caneca da feira da reforma agraria                                                                     3523
# i_adubo organico                                                                                              3171
# qt_adubo organico                                                                                             3171
# vl_tot_adubo organico                                                                                         3171
# i_livro - comunicacoes em tempos de crise                                                                     3504
# qt_livro - comunicacoes em tempos de crise                                                                    3504
# vl_tot_livro - comunicacoes em tempos de crise                                                                3504
# i_camisa mst (tamanho p) - vermelha                                                                           3488
# qt_camisa mst (tamanho p) - vermelha                                                                          3488
# vl_tot_camisa mst (tamanho p) - vermelha                                                                      3488
# i_camisa mst (tamanho                                                                                         3500
# qt_camisa mst (tamanho                                                                                        3500
# vl_tot_camisa mst (tamanho                                                                                    3500
# i_camisa mst (tamanho g) - vermelha                                                                           3474
# qt_camisa mst (tamanho g) - vermelha                                                                          3474
# vl_tot_camisa mst (tamanho g) - vermelha                                                                      3474
# i_berin                                                                                                       3107
# qt_berin                                                                                                      3107
# vl_tot_berin                                                                                                  3107
# i_camisa mst (tamanho m) - vermelha                                                                           3462
# qt_camisa mst (tamanho m) - vermelha                                                                          3462
# vl_tot_camisa mst (tamanho m) - vermelha                                                                      3462
# i_livro - dom fragoso e padre alfredinho entre nos                                                            3516
# qt_livro - dom fragoso e padre alfredinho entre nos                                                           3516
# vl_tot_livro - dom fragoso e padre alfredinho entre nos                                                       3516
# i_geleia de acerola                                                                                           3300
# qt_geleia de acerola                                                                                          3300
# vl_tot_geleia de acerola                                                                                      3300
# i_fava                                                                                                        3278
# qt_fava                                                                                                       3278
# vl_tot_fava                                                                                                   3278
# i_feijao verde                                                                                                2803
# qt_feijao verde                                                                                               2803
# vl_tot_feijao verde                                                                                           2803
# i_gergelim                                                                                                    3292
# qt_gergelim                                                                                                   3292
# vl_tot_gergelim                                                                                               3292
# i_linguica artesanal - apimentada                                                                             3298
# qt_linguica artesanal - apimentada                                                                            3298
# vl_tot_linguica artesanal - apimentada                                                                        3298
# i_linguica artesanal - condimentada                                                                           3202
# qt_linguica artesanal - condimentada                                                                          3202
# vl_tot_linguica artesanal - condimentada                                                                      3202
# i_linguica artesanal - tradicional                                                                            3203
# qt_linguica artesanal - tradicional                                                                           3203
# vl_tot_linguica artesanal - tradicional                                                                       3203
# i_livro - apontamentos sobre a "teoria do autoritarismo"                                                      3520
# qt_livro - apontamentos sobre a "teoria do autoritarismo"                                                     3520
# vl_tot_livro - apontamentos sobre a "teoria do autoritarismo"                                                 3520
# i_livro - introducao a filosofia de marx                                                                      3518
# qt_livro - introducao a filosofia de marx                                                                     3518
# vl_tot_livro - introducao a filosofia de marx                                                                 3518
# i_livro - o estado e a revolucao                                                                              3520
# qt_livro - o estado e a revolucao                                                                             3520
# vl_tot_livro - o estado e a revolucao                                                                         3520
# i_livro - os desafios da esquerda latino-americana                                                            3516
# qt_livro - os desafios da esquerda latino-americana                                                           3516
# vl_tot_livro - os desafios da esquerda latino-americana                                                       3516
# i_rapadura de caju                                                                                            3230
# qt_rapadura de caju                                                                                           3230
# vl_tot_rapadura de caju                                                                                       3230
# i_caju                                                                                                        3463
# qt_caju                                                                                                       3463
# vl_tot_caju                                                                                                   3463
# i_coco seco                                                                                                   3157
# qt_coco seco                                                                                                  3157
# vl_tot_coco seco                                                                                              3157
# i_melancia                                                                                                    3183
# qt_melancia                                                                                                   3183
# vl_tot_melancia                                                                                               3183
# i_tomate cereja                                                                                               3177
# qt_tomate cereja                                                                                              3177
# vl_tot_tomate cereja                                                                                          3177
# i_maxixe                                                                                                      3392
# qt_maxixe                                                                                                     3392
# vl_tot_maxixe                                                                                                 3392
# i_livro - autoritarismo contra a universidade - o desafio de popularizar a defesa da educacao publica         3515
# qt_livro - autoritarismo contra a universidade - o desafio de popularizar a defesa da educacao publica        3515
# vl_tot_livro - autoritarismo contra a universidade - o desafio de popularizar a defesa da educacao publica    3515
# i_quentinha - baiao e galinha caipira                                                                         3522
# qt_quentinha - baiao e galinha caipira                                                                        3522
# vl_tot_quentinha - baiao e galinha caipira                                                                    3522
# i_pimentinha de cheiro                                                                                        3285
# qt_pimentinha de cheiro                                                                                       3285
# vl_tot_pimentinha de cheiro                                                                                   3285
# i_livro - imaginacao e criacao na infancia                                                                    3516
# qt_livro - imaginacao e criacao na infancia                                                                   3516
# vl_tot_livro - imaginacao e criacao na infancia                                                               3516
# i_quentinha - baiao e carneiro                                                                                3525
# qt_quentinha - baiao e carneiro                                                                               3525
# vl_tot_quentinha - baiao e carneiro                                                                           3525
# i_livro - carrapicho                                                                                          3507
# qt_livro - carrapicho                                                                                         3507
# vl_tot_livro - carrapicho                                                                                     3507
# i_quentinha  - arroz e carneiro                                                                               3523
# qt_quentinha  - arroz e carneiro                                                                              3523
# vl_tot_quentinha  - arroz e carneiro                                                                          3523
# i_quentinha - arroz e peixada                                                                                 3521
# qt_quentinha - arroz e peixada                                                                                3521
# vl_tot_quentinha - arroz e peixada                                                                            3521
# i_livro - hasteemos a bandeira colorida - diversidade sexual e de genero no brasil                            3524
# qt_livro - hasteemos a bandeira colorida - diversidade sexual e de genero no brasil                           3524
# vl_tot_livro - hasteemos a bandeira colorida - diversidade sexual e de genero no brasil                       3524
# i_goma fresca para tapioca                                                                                    3129
# qt_goma fresca para tapioca                                                                                   3129
# vl_tot_goma fresca para tapioca                                                                               3129
# i_fuba de milho                                                                                               3406
# qt_fuba de milho                                                                                              3406
# vl_tot_fuba de milho                                                                                          3406
# i_mel de cana                                                                                                 3445
# qt_mel de cana                                                                                                3445
# vl_tot_mel de cana                                                                                            3445
# i_doce de caju                                                                                                3316
# qt_doce de caju                                                                                               3316
# vl_tot_doce de caju                                                                                           3316
# i_camiseta basqueteira - tamanho eg                                                                           3526
# qt_camiseta basqueteira - tamanho eg                                                                          3526
# vl_tot_camiseta basqueteira - tamanho eg                                                                      3526
# i_camiseta basqueteira - tamanho gg                                                                           3525
# qt_camiseta basqueteira - tamanho gg                                                                          3525
# vl_tot_camiseta basqueteira - tamanho gg                                                                      3525
# i_livro - lenin e a revolucao                                                                                 3522
# qt_livro - lenin e a revolucao                                                                                3522
# vl_tot_livro - lenin e a revolucao                                                                            3522
# i_camiseta basqueteira - tamanho m                                                                            3523
# qt_camiseta basqueteira - tamanho m                                                                           3523
# vl_tot_camiseta basqueteira - tamanho m                                                                       3523
# i_doce de mamao com coco                                                                                      3519
# qt_doce de mamao com coco                                                                                     3519
# vl_tot_doce de mamao com coco                                                                                 3519
# i_livro - a reforma empresarial da educacao                                                                   3526
# qt_livro - a reforma empresarial da educacao                                                                  3526
# vl_tot_livro - a reforma empresarial da educacao                                                              3526
# i_livro - esquerdismo - doenca infantil do comunismo                                                          3522
# qt_livro - esquerdismo - doenca infantil do comunismo                                                         3522
# vl_tot_livro - esquerdismo - doenca infantil do comunismo                                                     3522
# i_camiseta basqueteira - tamanho g                                                                            3525
# qt_camiseta basqueteira - tamanho g                                                                           3525
# vl_tot_camiseta basqueteira - tamanho g                                                                       3525
# i_livro - para a questao judaica                                                                              3526
# qt_livro - para a questao judaica                                                                             3526
# vl_tot_livro - para a questao judaica                                                                         3526
# i_cafe guaii moido (500g)                                                                                     3401
# qt_cafe guaii moido (500g)                                                                                    3401
# vl_tot_cafe guaii moido (500g)                                                                                3401
# i_arroz branco - agulhinha (5kg)                                                                              3429
# qt_arroz branco - agulhinha (5kg)                                                                             3429
# vl_tot_arroz branco - agulhinha (5kg)                                                                         3429
# i_cachaca veredas da terra                                                                                    3435
# qt_cachaca veredas da terra                                                                                   3435
# vl_tot_cachaca veredas da terra                                                                               3435
# i_farinha de mandioca branca (torradinha)                                                                     3395
# qt_farinha de mandioca branca (torradinha)                                                                    3395
# vl_tot_farinha de mandioca branca (torradinha)                                                                3395
# i_cafe guaii em graos (250g)                                                                                  3488
# qt_cafe guaii em graos (250g)                                                                                 3488
# vl_tot_cafe guaii em graos (250g)                                                                             3488
# i_creme de nata                                                                                               3408
# qt_creme de nata                                                                                              3408
# vl_tot_creme de nata                                                                                          3408
# i_mel de caju                                                                                                 3504
# qt_mel de caju                                                                                                3504
# vl_tot_mel de caju                                                                                            3504
# i_doce de banana com canela                                                                                   3512
# qt_doce de banana com canela                                                                                  3512
# vl_tot_doce de banana com canela                                                                              3512
# i_livro - dialetica do marxismo cultural                                                                      3525
# qt_livro - dialetica do marxismo cultural                                                                     3525
# vl_tot_livro - dialetica do marxismo cultural                                                                 3525
# i_livro -  o colapso da democracia no brasil - da constituicao ao golpe de 2016                               3526
# qt_livro -  o colapso da democracia no brasil - da constituicao ao golpe de 2016                              3526
# vl_tot_livro -  o colapso da democracia no brasil - da constituicao ao golpe de 2016                          3526
# i_livro - quando vier o silencio - o problema mineral brasileiro                                              3524
# qt_livro - quando vier o silencio - o problema mineral brasileiro                                             3524
# vl_tot_livro - quando vier o silencio - o problema mineral brasileiro                                         3524
# i_alho temperado                                                                                              3262
# qt_alho temperado                                                                                             3262
# vl_tot_alho temperado                                                                                         3262
# i_mascara de tecido mst - cor vermelha                                                                        3467
# qt_mascara de tecido mst - cor vermelha                                                                       3467
# vl_tot_mascara de tecido mst - cor vermelha                                                                   3467
# i_mascara de tecido mst - cor branca                                                                          3491
# qt_mascara de tecido mst - cor branca                                                                         3491
# vl_tot_mascara de tecido mst - cor branca                                                                     3491
# i_trufas de chocolate branco                                                                                  3496
# qt_trufas de chocolate branco                                                                                 3496
# vl_tot_trufas de chocolate branco                                                                             3496
# i_trufas de chocolate preto                                                                                   3456
# qt_trufas de chocolate preto                                                                                  3456
# vl_tot_trufas de chocolate preto                                                                              3456
# i_repelente natural                                                                                           3450
# qt_repelente natural                                                                                          3450
# vl_tot_repelente natural                                                                                      3450
# i_livro - o pensamento africano no seculo xx                                                                  3521
# qt_livro - o pensamento africano no seculo xx                                                                 3521
# vl_tot_livro - o pensamento africano no seculo xx                                                             3521
# i_livro - os sem terrinha                                                                                     3521
# qt_livro - os sem terrinha                                                                                    3521
# vl_tot_livro - os sem terrinha                                                                                3521
# i_acucar mascavo organico                                                                                     3398
# qt_acucar mascavo organico                                                                                    3398
# vl_tot_acucar mascavo organico                                                                                3398
# i_sacola da feira da reforma agraria                                                                          3498
# qt_sacola da feira da reforma agraria                                                                         3498
# vl_tot_sacola da feira da reforma agraria                                                                     3498
# i_suco de uva                                                                                                 3327
# qt_suco de uva                                                                                                3327
# vl_tot_suco de uva                                                                                            3327
# i_cafe popular                                                                                                3384
# qt_cafe popular                                                                                               3384
# vl_tot_cafe popular                                                                                           3384
# i_aromatizante de ambiente citronela                                                                          3484
# qt_aromatizante de ambiente citronela                                                                         3484
# vl_tot_aromatizante de ambiente citronela                                                                     3484
# i_bone mst - movimento lgbt                                                                                   3513
# qt_bone mst - movimento lgbt                                                                                  3513
# vl_tot_bone mst - movimento lgbt                                                                              3513
# i_blusas de renda [ manga curta ]  2                                                                          3526
# qt_blusas de renda [ manga curta ]  2                                                                         3526
# vl_tot_blusas de renda [ manga curta ]  2                                                                     3526
# i_blusas de renda [ manga curta ]                                                                             3526
# qt_blusas de renda [ manga curta ]                                                                            3526
# vl_tot_blusas de renda [ manga curta ]                                                                        3526
# i_ata                                                                                                         3468
# qt_ata                                                                                                        3468
# vl_tot_ata                                                                                                    3468
# i_arroz integral (a vacuo)                                                                                    3458
# qt_arroz integral (a vacuo)                                                                                   3458
# vl_tot_arroz integral (a vacuo)                                                                               3458
# i_milho verde                                                                                                 3471
# qt_milho verde                                                                                                3471
# vl_tot_milho verde                                                                                            3471
# i_mel em sache 500g                                                                                           3516
# qt_mel em sache 500g                                                                                          3516
# vl_tot_mel em sache 500g                                                                                      3516
# i_doce de leite e goiaba                                                                                      3484
# qt_doce de leite e goiaba                                                                                     3484
# vl_tot_doce de leite e goiaba                                                                                 3484
# i_farinha d'agua                                                                                              3518
# qt_farinha d'agua                                                                                             3518
# vl_tot_farinha d'agua                                                                                         3518
# i_kit tampa de tigela redonda em tecido                                                                       3517
# qt_kit tampa de tigela redonda em tecido                                                                      3517
# vl_tot_kit tampa de tigela redonda em tecido                                                                  3517
# i_boneca sorriso                                                                                              3521
# qt_boneca sorriso                                                                                             3521
# vl_tot_boneca sorriso                                                                                         3521
# i_mel em sache 250g                                                                                           3518
# qt_mel em sache 250g                                                                                          3518
# vl_tot_mel em sache 250g                                                                                      3518
# i_cafe terra de sabores tradicional (250g)                                                                    3505
# qt_cafe terra de sabores tradicional (250g)                                                                   3505
# vl_tot_cafe terra de sabores tradicional (250g)                                                               3505
# i_pimenta do reino preta com moedor terra de sabores                                                          3507
# qt_pimenta do reino preta com moedor terra de sabores                                                         3507
# vl_tot_pimenta do reino preta com moedor terra de sabores                                                     3507
# i_cafe terra de sabores superior                                                                              3457
# qt_cafe terra de sabores superior                                                                             3457
# vl_tot_cafe terra de sabores superior                                                                         3457
# i_livro phenix caixeiral: historia de uma biblioteca                                                          3520
# qt_livro phenix caixeiral: historia de uma biblioteca                                                         3520
# vl_tot_livro phenix caixeiral: historia de uma biblioteca                                                     3520
# i_bone do mst preto                                                                                           3514
# qt_bone do mst preto                                                                                          3514
# vl_tot_bone do mst preto                                                                                      3514
# i_aromatizante de cravo                                                                                       3525
# qt_aromatizante de cravo                                                                                      3525
# vl_tot_aromatizante de cravo                                                                                  3525
# i_livro somos os que foram                                                                                    3526
# qt_livro somos os que foram                                                                                   3526
# vl_tot_livro somos os que foram                                                                               3526
# i_chocolate 90g 56% cacau                                                                                     3508
# qt_chocolate 90g 56% cacau                                                                                    3508
# vl_tot_chocolate 90g 56% cacau                                                                                3508
# i_bebida lactea sabor chocolate uht 200ml - terrinha                                                          3497
# qt_bebida lactea sabor chocolate uht 200ml - terrinha                                                         3497
# vl_tot_bebida lactea sabor chocolate uht 200ml - terrinha                                                     3497
# i_chocolate 90g 70% cacau                                                                                     3508
# qt_chocolate 90g 70% cacau                                                                                    3508
# vl_tot_chocolate 90g 70% cacau                                                                                3508
# i_chocolate 90g 100% cacau                                                                                    3526
# qt_chocolate 90g 100% cacau                                                                                   3526
# vl_tot_chocolate 90g 100% cacau                                                                               3526
# i_cachaca veredas da terra - amburana                                                                         3501
# qt_cachaca veredas da terra - amburana                                                                        3501
# vl_tot_cachaca veredas da terra - amburana                                                                    3501
# i_camisa coletivo lgbt sem terra  tamanho p                                                                   3526
# qt_camisa coletivo lgbt sem terra  tamanho p                                                                  3526
# vl_tot_camisa coletivo lgbt sem terra  tamanho p                                                              3526
# i_camisa coletivo lgbt sem terra  tamanho m                                                                   3526
# qt_camisa coletivo lgbt sem terra  tamanho m                                                                  3526
# vl_tot_camisa coletivo lgbt sem terra  tamanho m                                                              3526
# i_graviola                                                                                                    3519
# qt_graviola                                                                                                   3519
# vl_tot_graviola                                                                                               3519
# i_rapadura de cana de acucar                                                                                  3506
# qt_rapadura de cana de acucar                                                                                 3506
# vl_tot_rapadura de cana de acucar                                                                             3506
# i_camisa mst (tamanho pp) - vermelha                                                                          3523
# qt_camisa mst (tamanho pp) - vermelha                                                                         3523
# vl_tot_camisa mst (tamanho pp) - vermelha                                                                     3523
# i_aromatizante de canela                                                                                      3524
# qt_aromatizante de canela                                                                                     3524
# vl_tot_aromatizante de canela                                                                                 3524
# i_carne de caju 1k                                                                                            3393
# qt_carne de caju 1k                                                                                           3393
# vl_tot_carne de caju 1k                                                                                       3393
# i_filet de peixe  [ traira ] 1k                                                                               3506
# qt_filet de peixe  [ traira ] 1k                                                                              3506
# vl_tot_filet de peixe  [ traira ] 1k                                                                          3506
# i_biscoito de castanha integral 150g                                                                          3500
# qt_biscoito de castanha integral 150g                                                                         3500
# vl_tot_biscoito de castanha integral 150g                                                                     3500
# i_balinhas de tamarindo                                                                                       3513
# qt_balinhas de tamarindo                                                                                      3513
# vl_tot_balinhas de tamarindo                                                                                  3513
# i_cheiro verde [ maco ]                                                                                       3507
# qt_cheiro verde [ maco ]                                                                                      3507
# vl_tot_cheiro verde [ maco ]                                                                                  3507
# i_pimentao [ 500g ]                                                                                           3510
# qt_pimentao [ 500g ]                                                                                          3510
# vl_tot_pimentao [ 500g ]                                                                                      3510
# i_abobrinha                                                                                                   3516
# qt_abobrinha                                                                                                  3516
# vl_tot_abobrinha                                                                                              3516
# i_quiabo [ kg ]                                                                                               3521
# qt_quiabo [ kg ]                                                                                              3521
# vl_tot_quiabo [ kg ]                                                                                          3521
# i_pepino amarelo [ unidade ]                                                                                  3524
# qt_pepino amarelo [ unidade ]                                                                                 3524
# vl_tot_pepino amarelo [ unidade ]                                                                             3524
# dtype: int64

# %%
pd.set_option("display.max_rows", 10)

# %% [markdown]
# Nas colunas de quantidade e preço é preciso trocar nulo por zero; nas colunas de produto nulo por False.

# %%
# Preenchendo as colunas numéricas com 0
for nome_col in df_ped.columns:
    if ('qt_' in nome_col) or ('vl_' in nome_col):
        df_ped[nome_col].fillna(0,inplace=True)

# Restaram somente as colunas de produtos, portanto podemos colocar False em tudo que estiver NaN DataFrame.
df_ped.fillna(False,inplace=True)

# %% [markdown]
# Vejamos como ficou o DataFrame de pedidos.

# %%
df_ped.head()
# Out:
#    data_pedido hora_pedido  id_cliente    bairro_pedido cidade_pedido  \
# 54  2020-07-03    11:30:53          39          aldeota     fortaleza
# 56  2020-07-03    11:32:27          38      sao gerardo     fortaleza
# 59  2020-07-03    11:38:01          35    manoel satiro     fortaleza
# 60  2020-07-03    11:38:27          33  rodolfo teofilo     fortaleza
# 64  2020-07-03    11:49:13          40  rodolfo teofilo     fortaleza
#
#    cep_pedido            tipo_pagamento   agente  i_agua de coco  \
# 54   60150060  Pagar ao retirar na loja  android            True
# 56   60320105         Cartão de Crédito  windows           False
# 59   60713480         Cartão de Crédito  windows           False
# 60   60431075      Débito/Transferência  android            True
# 64   60430660         Cartão de Crédito  android           False
#
#     qt_agua de coco  ...  vl_tot_pimentao [ 500g ]  i_abobrinha  qt_abobrinha  \
# 54              2.0  ...                       0.0        False           0.0
# 56              0.0  ...                       0.0        False           0.0
# 59              0.0  ...                       0.0        False           0.0
# 60              2.0  ...                       0.0        False           0.0
# 64              0.0  ...                       0.0        False           0.0
#
#     vl_tot_abobrinha  i_quiabo [ kg ]  qt_quiabo [ kg ]  vl_tot_quiabo [ kg ]  \
# 54               0.0            False               0.0                   0.0
# 56               0.0            False               0.0                   0.0
# 59               0.0            False               0.0                   0.0
# 60               0.0            False               0.0                   0.0
# 64               0.0            False               0.0                   0.0
#
#     i_pepino amarelo [ unidade ]  qt_pepino amarelo [ unidade ]  \
# 54                         False                            0.0
# 56                         False                            0.0
# 59                         False                            0.0
# 60                         False                            0.0
# 64                         False                            0.0
#
#     vl_tot_pepino amarelo [ unidade ]
# 54                                0.0
# 56                                0.0
# 59                                0.0
# 60                                0.0
# 64                                0.0
#
# [5 rows x 538 columns]

# %% [markdown]
# ## Criação de DataFrame de clientes.

# %% [markdown]
# Há análises que podem ser feitas baseando-se no perfil dos clientes, e não nos pedidos. Vamos criar um DataFrame com uma linha para cada cliente, totalizando valores e quantidades de itens de todas as compras.

# %%
# Esta função troca os nomes das colunas totalizadoras de valores e itens de forma a ficarem mais condizentes com a
# proposta do DataFrame.
def troca_nome_cols_tot(coluna):
    if coluna == 'vl_final_pedido':
        return 'vl_total_compras'
    elif coluna == 'qt_final_itens':
        return 'qt_total_itens'
    else:
        return coluna

cols_interesse = list()

for coluna in df_ped.columns:
    if 'vl_' in coluna or 'qt_' in coluna:
        cols_interesse.append(coluna)

dic_cols_interesse = dict()
for col_interesse in cols_interesse:
    dic_cols_interesse[col_interesse] = ['sum']

df_cli = df_ped.groupby('id_cliente').agg(dic_cols_interesse)
df_cli.columns = [col[0] for col in df_cli.columns] # Para índice deixar de ser tuplas com  nome do campo e 'sum'.
df_cli.columns = [troca_nome_cols_tot(coluna) for coluna in df_cli.columns]

# Acrescentando a coluna com o total de pedidos
qt_pedidos = df_ped.groupby('id_cliente').size()
qt_pedidos.name = 'qt_tot_pedidos'
df_cli = df_cli.join(qt_pedidos)
df_cli = df_cli.round(2) # Para eliminar dízimas periódicas

# %% [markdown]
# Vamos ver como ficou o DataFrame de clientes.

# %%
df_cli.head()
# Out:
#             qt_agua de coco  vl_tot_agua de coco  vl_total_compras  \
# id_cliente
# 31                     32.0                 96.0           2109.05
# 33                      2.0                  6.0            290.80
# 34                     61.0                183.0           9108.60
# 35                      0.0                  0.0            774.05
# 36                      0.0                  0.0            190.80
#
#             qt_total_itens  qt_cajuina  vl_tot_cajuina  qt_couve  \
# id_cliente
# 31                     214         6.0            60.0       6.0
# 33                      34         0.0             0.0       4.0
# 34                     882         7.0            70.0      58.0
# 35                      69         1.0            10.0       0.0
# 36                      32         0.0             0.0       6.0
#
#             vl_tot_couve  qt_doce de leite  vl_tot_doce de leite  ...  \
# id_cliente                                                        ...
# 31                  18.0               2.0                  24.0  ...
# 33                  12.0               0.0                   0.0  ...
# 34                 174.0               7.0                  84.0  ...
# 35                   0.0               1.0                  12.0  ...
# 36                  18.0               0.0                   0.0  ...
#
#             vl_tot_cheiro verde [ maco ]  qt_pimentao [ 500g ]  \
# id_cliente
# 31                                   0.0                   0.0
# 33                                   0.0                   0.0
# 34                                   0.0                   0.0
# 35                                   0.0                   0.0
# 36                                   0.0                   0.0
#
#             vl_tot_pimentao [ 500g ]  qt_abobrinha  vl_tot_abobrinha  \
# id_cliente
# 31                               0.0           0.0               0.0
# 33                               0.0           0.0               0.0
# 34                               0.0           0.0               0.0
# 35                               0.0           0.0               0.0
# 36                               0.0           0.0               0.0
#
#             qt_quiabo [ kg ]  vl_tot_quiabo [ kg ]  \
# id_cliente
# 31                       0.0                   0.0
# 33                       0.0                   0.0
# 34                       0.0                   0.0
# 35                       0.0                   0.0
# 36                       0.0                   0.0
#
#             qt_pepino amarelo [ unidade ]  vl_tot_pepino amarelo [ unidade ]  \
# id_cliente
# 31                                    0.0                                0.0
# 33                                    0.0                                0.0
# 34                                    0.0                                0.0
# 35                                    0.0                                0.0
# 36                                    0.0                                0.0
#
#             qt_tot_pedidos
# id_cliente
# 31                      12
# 33                       4
# 34                      12
# 35                       4
# 36                       3
#
# [5 rows x 355 columns]

# %% [markdown]
# ## Salvando os DataFrames para uso posterior

# %%
df.to_csv('arquivos/pedidos_long_final.csv',index=False)
df_ped.to_csv('arquivos/pedidos_wide_final.csv',index_label='id_pedido')
df_cli.to_csv('arquivos/clientes_final.csv')
